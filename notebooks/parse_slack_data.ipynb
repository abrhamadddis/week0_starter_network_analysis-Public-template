# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os, sys
import re
import json
import glob
import datetime
from collections import Counter
from matplotlib import pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
# Add parent directory to path to import modules from src
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)

from src.loader import SlackDataLoader
import src.utils as utils

# %% [markdown]
# ### Columns we can get from a slack message<br>
#
# message_type, message_content, sender_id, time_sent, message_distribution, time_thread_start, reply_count, reply_user_count, time_thread_end, reply_users

# %% [markdown]
# From a single slack message, we can get <br>
#
# 1. The message<br>
# 2. Type (message, file, link, etc)<br>
# 3. The sender_id (assigned by slack)<br>
# 4. The time the message was sent<br>
# 5. The team (i don't know what that is now)<br>
# 6. The type of the message (broadcast message, inhouse, just messgae)<br>
# 7. The thread the message generated (from here we can go):<br>
#     7.1 Text/content of the message<br>
#     7.2 The thread time of the message<br>
#     7.3 The thread count (reply count)<br>
#     7.4 The number of user that reply the message (count of users that participated in the thread)<br>
#     7.5 The time the last thread message was sent <br>
#     7.6 The users that participated in the thread (their ids are stored as well)<br>

# %%
import glob
import pandas as pd
# combine all json file in all-weeks8-9
def slack_parser(path_channel):
    """ parse slack data to extract useful informations from the json file
        step of execution
        1. Import the required modules
        2. read all json file from the provided path
        3. combine all json files in the provided path
        4. extract all required informations from the slack data
        5. convert to dataframe and merge all
        6. reset the index and return dataframe
    """

    # specify path to get json files
    combined = []
    for json_file in glob.glob(f"{path_channel}/*.json"): # type: ignore
        with open(json_file, 'r', encoding="utf8") as slack_data:
            file = json.load(slack_data)
            combined.append(file)
    print(combined)
    # loop through all json files and extract required informations
    dflist = []
    for slack_data in combined:

        msg_type, msg_content, sender_id, time_msg, msg_dist, time_thread_st, reply_users, \
        reply_count, reply_users_count, tm_thread_end = [],[],[],[],[],[],[],[],[],[]

        for row in slack_data:
            if 'bot_id' in row.keys():
                continue
            else:
                msg_type.append(row['type'])
                msg_content.append(row['text'])
                if 'user_profile' in row.keys(): sender_id.append(row['user_profile']['real_name'])
                else: sender_id.append('Not provided')
                time_msg.append(row['ts'])
                if 'blocks' in row.keys() and len(row['blocks'][0]['elements'][0]['elements']) != 0 :
                     msg_dist.append(row['blocks'][0]['elements'][0]['elements'][0]['type'])
                else: msg_dist.append('reshared')
                if 'thread_ts' in row.keys():
                    time_thread_st.append(row['thread_ts'])
                else:
                    time_thread_st.append(0)
                if 'reply_users' in row.keys(): reply_users.append(",".join(row['reply_users'])) 
                else:    reply_users.append(0)
                if 'reply_count' in row.keys():
                    reply_count.append(row['reply_count'])
                    reply_users_count.append(row['reply_users_count'])
                    tm_thread_end.append(row['latest_reply'])
                else:
                    reply_count.append(0)
                    reply_users_count.append(0)
                    tm_thread_end.append(0)
        data = zip(msg_type, msg_content, sender_id, time_msg, msg_dist, time_thread_st,
        reply_count, reply_users_count, reply_users, tm_thread_end)
        columns = ['msg_type', 'msg_content', 'sender_name', 'msg_sent_time', 'msg_dist_type',
         'time_thread_start', 'reply_count', 'reply_users_count', 'reply_users', 'tm_thread_end']

        df = pd.DataFrame(data=data, columns=columns)
        df = df[df['sender_name'] != 'Not provided']
        dflist.append(df)

    dfall = pd.concat(dflist, ignore_index=True)
    dfall['channel'] = path_channel.split('/')[-1].split('.')[0]        
    dfall = dfall.reset_index(drop=True)
    
    return dfall


def parse_slack_reaction(path, channel):
    """get reactions"""
    dfall_reaction = pd.DataFrame()
    combined = []
    for json_file in glob.glob(f"{path}*.json"):
        with open(json_file, 'r') as slack_data:
            file = json.load(slack_data)
            combined.append(file)
    print(combined)
    reaction_name, reaction_count, reaction_users, msg, user_id = [], [], [], [], []

    for k in combined:
        slack_data = json.load(open(k.name, 'r', encoding="utf-8"))
        
        for i_count, i in enumerate(slack_data):
            if 'reactions' in i.keys():
                for j in range(len(i['reactions'])):
                    msg.append(i['text'])
                    user_id.append(i['user'])
                    reaction_name.append(i['reactions'][j]['name'])
                    reaction_count.append(i['reactions'][j]['count'])
                    reaction_users.append(",".join(i['reactions'][j]['users']))
                
    data_reaction = zip(reaction_name, reaction_count, reaction_users, msg, user_id)
    columns_reaction = ['reaction_name', 'reaction_count', 'reaction_users_count', 'message', 'user_id']
    df_reaction = pd.DataFrame(data=data_reaction, columns=columns_reaction)
    df_reaction['channel'] = channel
    return df_reaction

def get_community_participation(path):
    """ specify path to get json files"""
    combined = []
    comm_dict = {}
    for json_file in glob.glob(f"{path}*.json"):
        with open(json_file, 'r') as slack_data:
            combined.append(slack_data)
    # print(f"Total json files is {len(combined)}")
    for i in combined:
        a = json.load(open(i.name, 'r', encoding='utf-8'))

        for msg in a:
            if 'replies' in msg.keys():
                for i in msg['replies']:
                    comm_dict[i['user']] = comm_dict.get(i['user'], 0)+1
    return comm_dict

# %%
def convert_2_timestamp(column, data):
    """convert from unix time to readable timestamp
        args: column: columns that needs to be converted to timestamp
                data: data that has the specified column
    """
    if column in data.columns.values:
        timestamp_ = []
        for time_unix in data[column]:
            if time_unix == 0:
                timestamp_.append(0)
            else:
                a = datetime.datetime.fromtimestamp(float(time_unix))
                timestamp_.append(a.strftime('%Y-%m-%d %H:%M:%S'))
        return timestamp_
    else: 
        print(f"{column} not in data")

def get_tagged_users(df):
    """get all @ in the messages"""

    return df['msg_content'].map(lambda x: re.findall(r'@U\w+', x))


    
def map_userid_2_realname(user_profile: dict, comm_dict: dict, plot=False):
    """
    map slack_id to realnames
    user_profile: a dictionary that contains users info such as real_names
    comm_dict: a dictionary that contains slack_id and total_message sent by that slack_id
    """
    user_dict = {} # to store the id
    real_name = [] # to store the real name
    ac_comm_dict = {} # to store the mapping
    count = 0
    # collect all the real names
    for i in range(len(user_profile['profile'])):
        real_name.append(dict(user_profile['profile'])[i]['real_name'])

    # loop the slack ids
    for i in user_profile['id']:
        user_dict[i] = real_name[count]
        count += 1

    # to store mapping
    for i in comm_dict:
        if i in user_dict:
            ac_comm_dict[user_dict[i]] = comm_dict[i]

    ac_comm_dict = pd.DataFrame(data= zip(ac_comm_dict.keys(), ac_comm_dict.values()),
    columns=['LearnerName', '# of Msg sent in Threads']).sort_values(by='# of Msg sent in Threads', ascending=False)
    
    if plot:
        ac_comm_dict.plot.bar(figsize=(15, 7.5), x='LearnerName', y='# of Msg sent in Threads')
        plt.title('Student based on Message sent in thread', size=20)
        
    return ac_comm_dict

# %%
path = ("../data/all-week1")
out_put1=slack_parser(path)
# Out:
# [[{'client_msg_id': '228f2c2e-8314-4547-a626-19cd860646ed', 'type': 'message', 'text': "Can I get more info on the where the telecommunications dataset comes from? I'd like to put the project on my resume.", 'user': 'U03UJN29Y4C', 'ts': '1667932405.677889', 'blocks': [{'type': 'rich_text', 'block_id': 'EZYF', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "Can I get more info on the where the telecommunications dataset comes from? I'd like to put the project on my resume."}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '9bf024280cf1', 'image_72': 'https://avatars.slack-edge.com/2022-10-08/4190947116101_9bf024280cf14dffb003_72.jpg', 'first_name': 'Michelle', 'real_name': 'Michelle Lewis', 'display_name': 'Michelle Lewis', 'team': 'T03U4J8HMUG', 'name': 'Michelle', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1667932405.677889', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1668159386.385809', 'reply_users': ['U03U93GNNVB', 'U03UJN29Y4C'], 'replies': [{'user': 'U03U93GNNVB', 'ts': '1668158796.869069'}, {'user': 'U03UJN29Y4C', 'ts': '1668159386.385809'}], 'is_locked': False, 'subscribed': False}], [{'type': 'message', 'subtype': 'channel_join', 'ts': '1660833152.776779', 'user': 'U03U9DB7REG', 'text': '<@U03U9DB7REG> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1660833720.941909', 'user': 'U03UKL27B0R', 'text': '<@U03UKL27B0R> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1660838314.204679', 'user': 'U03UL5LSTG9', 'text': '<@U03UL5LSTG9> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1660840086.510509', 'user': 'U03TT5KEYCF', 'text': '<@U03TT5KEYCF> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1660854364.777769', 'user': 'U03UYNR4TS4', 'text': '<@U03UYNR4TS4> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1660888172.562459', 'user': 'U03UP7V9Q57', 'text': '<@U03UP7V9Q57> has joined the channel'}], [{'client_msg_id': '397209f9-77f0-4980-9433-da354bddce55', 'type': 'message', 'text': '<@U03V8LHPDME> <@U03UKL27B0R> <@U03U9DB7REG> a little clarification on what link we are submitting for Interim please', 'user': 'U03U1FNPEUX', 'ts': '1661979057.581639', 'blocks': [{'type': 'rich_text', 'block_id': 'FFZ4', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'user', 'user_id': 'U03V8LHPDME'}, {'type': 'text', 'text': ' '}, {'type': 'user', 'user_id': 'U03UKL27B0R'}, {'type': 'text', 'text': ' '}, {'type': 'user', 'user_id': 'U03U9DB7REG'}, {'type': 'text', 'text': ' a little clarification on what link we are submitting for Interim please'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '37a12a7dbb92', 'image_72': 'https://avatars.slack-edge.com/2022-09-09/4058043481011_37a12a7dbb926b2c9c86_72.png', 'first_name': 'Joshua', 'real_name': 'Joshua Rhodes', 'display_name': 'Joshua Rhodes', 'team': 'T03U4J8HMUG', 'name': 'Joshua', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1661979057.581639', 'reply_count': 10, 'reply_users_count': 3, 'latest_reply': '1661979934.403769', 'reply_users': ['U03UVHCV6KB', 'U03UKL27B0R', 'U03U1FNPEUX'], 'replies': [{'user': 'U03UVHCV6KB', 'ts': '1661979653.154169'}, {'user': 'U03UVHCV6KB', 'ts': '1661979680.826439'}, {'user': 'U03UKL27B0R', 'ts': '1661979683.761039'}, {'user': 'U03U1FNPEUX', 'ts': '1661979690.936839'}, {'user': 'U03U1FNPEUX', 'ts': '1661979754.550649'}, {'user': 'U03UVHCV6KB', 'ts': '1661979765.042359'}, {'user': 'U03UVHCV6KB', 'ts': '1661979772.260639'}, {'user': 'U03UVHCV6KB', 'ts': '1661979775.690969'}, {'user': 'U03UKL27B0R', 'ts': '1661979865.548709'}, {'user': 'U03U1FNPEUX', 'ts': '1661979934.403769'}], 'is_locked': False, 'subscribed': False}, {'client_msg_id': 'c2d33173-94 ...

# %%
path = ("../data/all-week2")
out_put2=slack_parser(path)
# Out:
# [[{'client_msg_id': '2b6e8140-e4d0-4755-a3f0-20aa93685406', 'type': 'message', 'text': 'I need clarification on the interim submission please. Are Task 1.2 due tomorrow too?', 'user': 'U03UJN29Y4C', 'ts': '1661842959.461809', 'blocks': [{'type': 'rich_text', 'block_id': 'LIPC', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'I need clarification on the interim submission please. Are Task 1.2 due tomorrow too?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '9bf024280cf1', 'image_72': 'https://avatars.slack-edge.com/2022-10-08/4190947116101_9bf024280cf14dffb003_72.jpg', 'first_name': 'Michelle', 'real_name': 'Michelle Lewis', 'display_name': 'Michelle Lewis', 'team': 'T03U4J8HMUG', 'name': 'Michelle', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1661842959.461809', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1661843014.512219', 'reply_users': ['U03UG4Q7V42'], 'replies': [{'user': 'U03UG4Q7V42', 'ts': '1661843014.512219'}], 'is_locked': False, 'subscribed': False}, {'client_msg_id': '692e9bef-bc64-40bf-957d-a4c11cea7adb', 'type': 'message', 'text': 'yes check the deliverables section', 'user': 'U03UG4Q7V42', 'ts': '1661843014.512219', 'blocks': [{'type': 'rich_text', 'block_id': 'BVN/j', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'yes check the deliverables section'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '5bc346a85286', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3968048875651_5bc346a852866218ec6b_72.png', 'first_name': 'Phillip', 'real_name': 'Phillip Atkins', 'display_name': 'Phillip Atkins', 'team': 'T03U4J8HMUG', 'name': 'Phillip', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1661842959.461809', 'parent_user_id': 'U03UJN29Y4C'}, {'client_msg_id': '5eecc7b1-0d2c-4107-b684-5567382202c5', 'type': 'message', 'text': '<https://www.youtube.com/watch?v=8H6QmMQWPEI>', 'user': 'U03UG569P7U', 'ts': '1661844575.691419', 'blocks': [{'type': 'rich_text', 'block_id': 'X2c=3', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://www.youtube.com/watch?v=8H6QmMQWPEI'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '29bf17011a4a', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3968176356738_29bf17011a4a887b2730_72.png', 'first_name': 'Melissa', 'real_name': 'Melissa Ingram', 'display_name': 'Melissa Ingram', 'team': 'T03U4J8HMUG', 'name': 'Melissa', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://www.youtube.com/watch?v=8H6QmMQWPEI', 'thumb_url': 'https://i.ytimg.com/vi/8H6QmMQWPEI/hqdefault.jpg', 'thumb_width': 480, 'thumb_height': 360, 'video_html': '<iframe width="400" height="225" src="https://www.youtube.com/embed/8H6QmMQWPEI?feature=oembed&autoplay=1&iv_load_policy=3" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen title="A/B Testing"></iframe>', 'video_html_width': 400, 'video_html_height': 225, 'service_icon': 'https://a.slack-edge.com/80588/img/unfurl_icons/youtube.png', 'id': 1, 'original_url': 'https://www.youtube.com/watch?v=8H6QmMQWPEI', 'fallback': 'YouTube Video: A/B Testing', 'title': 'A/B Testing', 'title_link': 'https://www.youtube.com/watch?v=8H6QmMQWPEI', 'author_name': 'Udacity', 'author_link': 'https://www.youtube.com/c/Udacity', 'service_name': 'YouTube', 'service_url': 'https://www.youtube.com/'}]}, {'client_msg_id': 'faaf66a4-43df-426b-9776-e07088c6d735', 'type': 'message', 'text': '<https://www.youtube.com/watch?v=6uw0A3aKwMc>', 'user': 'U03UG569P7U', 'ts': '1661845145.429239', 'blocks': [{'type': 'rich_text', 'block_id': 'uQ3f', 'elements': [{'type': 'rich_text_section', 'elements': [ ...

# %%
path = ("../data/all-week3")
out_put3=slack_parser(path)
# Out:
# [[{'client_msg_id': '1f2a0af6-66db-47ed-a4a6-afc4bed2f2a9', 'type': 'message', 'text': '```  note: This error originates from a subprocess, and is likely not a problem with pip.\nerror: legacy-install-failure\n\n× Encountered error while trying to install package.\n╰─&gt; fbprophet\n\nnote: This is an issue with the package mentioned above, not pip.\nhint: See above for output from the failure.```\nSame thing for pystan\n<@U03UKL27B0R>', 'user': 'U03UH397319', 'ts': '1662708766.558739', 'blocks': [{'type': 'rich_text', 'block_id': 'f9gj', 'elements': [{'type': 'rich_text_preformatted', 'elements': [{'type': 'text', 'text': '  note: This error originates from a subprocess, and is likely not a problem with pip.\nerror: legacy-install-failure\n\n× Encountered error while trying to install package.\n╰─> fbprophet\n\nnote: This is an issue with the package mentioned above, not pip.\nhint: See above for output from the failure.'}], 'border': 0}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Same thing for pystan\n'}, {'type': 'user', 'user_id': 'U03UKL27B0R'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Brenda', 'real_name': 'Brenda Hernandez', 'display_name': 'Brenda Hernandez', 'team': 'T03U4J8HMUG', 'name': 'Brenda', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1662708766.558739', 'reply_count': 5, 'reply_users_count': 2, 'latest_reply': '1662711063.142079', 'reply_users': ['U03UUR571A5', 'U03UH397319'], 'replies': [{'user': 'U03UUR571A5', 'ts': '1662710973.572349'}, {'user': 'U03UH397319', 'ts': '1662710996.956299'}, {'user': 'U03UH397319', 'ts': '1662711000.524529'}, {'user': 'U03UH397319', 'ts': '1662711043.324969'}, {'user': 'U03UUR571A5', 'ts': '1662711063.142079'}], 'is_locked': False, 'subscribed': False}, {'type': 'message', 'text': "Guys I got this error when I try to deploy my git to streamlit. I can't figure out the fault.", 'files': [{'id': 'F041Q9T6PH8', 'created': 1662709058, 'timestamp': 1662709058, 'name': 'image.png', 'title': 'image.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U03UGB3T3MY', 'user_team': 'T03U4J8HMUG', 'editable': False, 'size': 19429, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T03U4J8HMUG-F041Q9T6PH8/image.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'url_private_download': 'https://files.slack.com/files-pri/T03U4J8HMUG-F041Q9T6PH8/download/image.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'media_display_type': 'unknown', 'thumb_64': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F041Q9T6PH8-d26ade2516/image_64.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_80': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F041Q9T6PH8-d26ade2516/image_80.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F041Q9T6PH8-d26ade2516/image_360.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360_w': 360, 'thumb_360_h': 107, 'thumb_480': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F041Q9T6PH8-d26ade2516/image_480.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_480_w': 480, 'thumb_480_h': 143, 'thumb_160': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F041Q9T6PH8-d26ade2516/image_160.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'original_w': 684, 'origi ...

# %%
path = ("../data/all-week4")
out_put4=slack_parser(path)
# Out:
# [[{'client_msg_id': 'e7306183-b2bf-4b37-8728-b86424c3407a', 'type': 'message', 'text': "I am struggling. I need help. The previous weeks have been very challenging for me. Sometimes, I don't even know how two steps connects. For example, I don't know which stage database population comes in and why it's needed. When I have multiple disconnections like this I feel overwhelmed and it affects my work for that week. \n\nI've realized that I work best when I have step by step guide of what needs to be done. I know that our tasks are not provided in that format but going forward it's the first thing I want to do on Mondays and I need you guys to help me with it.", 'user': 'U03UJN29Y4C', 'ts': '1663145743.087849', 'blocks': [{'type': 'rich_text', 'block_id': 'y8zsi', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "I am struggling. I need help. The previous weeks have been very challenging for me. Sometimes, I don't even know how two steps connects. For example, I don't know which stage database population comes in and why it's needed. When I have multiple disconnections like this I feel overwhelmed and it affects my work for that week. \n\nI've realized that I work best when I have step by step guide of what needs to be done. I know that our tasks are not provided in that format but going forward it's the first thing I want to do on Mondays and I need you guys to help me with it."}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '9bf024280cf1', 'image_72': 'https://avatars.slack-edge.com/2022-10-08/4190947116101_9bf024280cf14dffb003_72.jpg', 'first_name': 'Michelle', 'real_name': 'Michelle Lewis', 'display_name': 'Michelle Lewis', 'team': 'T03U4J8HMUG', 'name': 'Michelle', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1663145743.087849', 'reply_count': 9, 'reply_users_count': 3, 'latest_reply': '1663238634.273009', 'reply_users': ['U03UVHCV6KB', 'U03UJN29Y4C', 'U03UUN8M4RX'], 'replies': [{'user': 'U03UVHCV6KB', 'ts': '1663146566.049579'}, {'user': 'U03UJN29Y4C', 'ts': '1663147546.049229'}, {'user': 'U03UUN8M4RX', 'ts': '1663235624.866439'}, {'user': 'U03UUN8M4RX', 'ts': '1663235777.545819'}, {'user': 'U03UUN8M4RX', 'ts': '1663235868.453749'}, {'user': 'U03UUN8M4RX', 'ts': '1663235946.162009'}, {'user': 'U03UUN8M4RX', 'ts': '1663236081.899659'}, {'user': 'U03UJN29Y4C', 'ts': '1663238073.641649'}, {'user': 'U03UUN8M4RX', 'ts': '1663238634.273009'}], 'is_locked': False, 'subscribed': False}, {'client_msg_id': '9a8a1ecc-bbab-43e4-a73b-0a7d09969bca', 'type': 'message', 'text': "So, for week 4. This is as far as my understanding goes on the challenge. \n\n1. Read up extensively on LLP\n2.   Set up dvc and cml\n3.   jupyter notebooks: EDA on the datasets\n4.   Python: Prompts engineering using API (still not sure how to fine tune with this yet)\n5.  fastapi or flask API endpoint (I don't know how to go about this or even if it's step 5)\nSo guys, help me out here, if there's anything out of order or you have something to chip in on step 4 or 5, please reply.", 'user': 'U03UJN29Y4C', 'ts': '1663145914.649449', 'blocks': [{'type': 'rich_text', 'block_id': 'JMS', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'So, for week 4. This is as far as my understanding goes on the challenge. \n\n'}]}, {'type': 'rich_text_list', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Read up extensively on LLP'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': '  Set up dvc and cml'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': '  jupyter notebooks: EDA on the datasets'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': '  Python: Prompts engineering using API (still not sure how to fine tune with this yet)'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': " fastapi or flask API ...

# %%
path = ("../data/all-week5")
out_put5=slack_parser(path)
# Out:
# [[{'client_msg_id': 'ba1eaad7-3f17-42fa-8598-6f59b64ee643', 'type': 'message', 'text': "<!here>, aws instance is being setup for everyone in a group setup. Here is the group list and instruction to connect to the instance using ssh.\n\nGROUP 1: address: <http://g1.10academy.org|g1.10academy.org>\nUSER names:\nadijat_ojutomori\nakubazgi_gebremariam\namanuel_zewdu\namdework_asefa\nandenet_alexander\n\nGROUP 2: address: <http://g2.10academy.org|g2.10academy.org>\nUSER names:\nbirhanu_gebisa\nbirtukan_kuma\ndegaga_wolde\nemtinan_osman\nfisseha_estifanos\n\nGROUP 3: address: <http://g3.10academy.org|g3.10academy.org>\nUSER names:\ngedion_abebe\ngenet_dekebo\nhaylemicheal_mekonnen\njanerose_njogu\njosias_djossou\n\nGROUP 4: address: <http://g4.10academy.org|g4.10academy.org>\nUSER names:\nkibatu_woldemariam\nmargaret_chepkirui\nmichael_abebe\nmohammed_esamaldin\nnahom_habtemichael\n\nGROUP 5: address: <http://g5.10academy.org|g5.10academy.org>\nUSER names:\nnatnael_melese\nnatnael_zerihun\nniyomukiza_thamar\ntegisty_hailay\ntibarek_berassu\n\nGROUP 6: address: <http://g6.10academy.org|g6.10academy.org>\nUSER names:\nwangui_gachugu\nyishak_tadele\nyohanes_gutema\nyohans_samuel\nyonas_moges\n\nTo connect: `ssh -i &lt;path-to-private-key&gt; &lt;user_name&gt;@&lt;address&gt;`\nYou can use Remote-ssh  vscode extension by Microsoft  with 12M download add your connection detail there.\nGroup 1 instance is up and running. Group 1 members please connect to your instance and reply back to this thread if it's not working.\n\nGroup 2- 6 instances are not up yet.", 'user': 'U03UKL27B0R', 'ts': '1663919287.747249', 'blocks': [{'type': 'rich_text', 'block_id': 'rZD', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'here'}, {'type': 'text', 'text': ', aws instance is being setup for everyone in a group setup. Here is the group list and instruction to connect to the instance using ssh.\n\nGROUP 1: address: '}, {'type': 'link', 'url': 'http://g1.10academy.org', 'text': 'g1.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\nadijat_ojutomori\nakubazgi_gebremariam\namanuel_zewdu\namdework_asefa\nandenet_alexander\n\nGROUP 2: address: '}, {'type': 'link', 'url': 'http://g2.10academy.org', 'text': 'g2.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\nbirhanu_gebisa\nbirtukan_kuma\ndegaga_wolde\nemtinan_osman\nfisseha_estifanos\n\nGROUP 3: address: '}, {'type': 'link', 'url': 'http://g3.10academy.org', 'text': 'g3.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\ngedion_abebe\ngenet_dekebo\nhaylemicheal_mekonnen\njanerose_njogu\njosias_djossou\n\nGROUP 4: address: '}, {'type': 'link', 'url': 'http://g4.10academy.org', 'text': 'g4.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\nkibatu_woldemariam\nmargaret_chepkirui\nmichael_abebe\nmohammed_esamaldin\nnahom_habtemichael\n\nGROUP 5: address: '}, {'type': 'link', 'url': 'http://g5.10academy.org', 'text': 'g5.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\nnatnael_melese\nnatnael_zerihun\nniyomukiza_thamar\ntegisty_hailay\ntibarek_berassu\n\nGROUP 6: address: '}, {'type': 'link', 'url': 'http://g6.10academy.org', 'text': 'g6.10academy.org'}, {'type': 'text', 'text': '\nUSER names:\nwangui_gachugu\nyishak_tadele\nyohanes_gutema\nyohans_samuel\nyonas_moges\n\nTo connect: '}, {'type': 'text', 'text': 'ssh -i <path-to-private-key> <user_name>@<address>', 'style': {'code': True}}, {'type': 'text', 'text': "\nYou can use Remote-ssh  vscode extension by Microsoft  with 12M download add your connection detail there.\nGroup 1 instance is up and running. Group 1 members please connect to your instance and reply back to this thread if it's not working.\n\nGroup 2- 6 instances are not up yet."}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '85058b6ca368', 'image_72': 'https://avatars.slack-edge.com/2022-08-18/3961513756852_85058b6ca368839d0014_72.png', 'first_name': 'B ...

# %%
sample_data = [out_put1, out_put2, out_put3, out_put4, out_put5]

# %%
week_1_5_sample_data = pd.concat(sample_data, ignore_index=True)

# %%
week_1_5_sample_data.shape
# Out:
# (1945, 11)

# %%
def get_top_20_user(data, channel='Random'):
    """get user with the highest number of message sent to any channel"""

    data['sender_name'].value_counts()[:20].plot.bar(figsize=(15, 7.5))
    plt.title(f'Top 20 Message Senders in #{channel} channels', size=15, fontweight='bold')
    plt.xlabel("Sender Name", size=18); plt.ylabel("Frequency", size=14);
    plt.xticks(size=12); plt.yticks(size=12);
    plt.show()

    data['sender_name'].value_counts()[-10:].plot.bar(figsize=(15, 7.5))
    plt.title(f'Bottom 10 Message Senders in #{channel} channels', size=15, fontweight='bold')
    plt.xlabel("Sender Name", size=18); plt.ylabel("Frequency", size=14);
    plt.xticks(size=12); plt.yticks(size=12);
    plt.show()

def draw_avg_reply_count(data, channel='Random'):
    """who commands many reply?"""

    data.groupby('sender_name')['reply_count'].mean().sort_values(ascending=False)[:20]\
        .plot(kind='bar', figsize=(15,7.5));
    plt.title(f'Average Number of reply count per Sender in #{channel}', size=20, fontweight='bold')
    plt.xlabel("Sender Name", size=18); plt.ylabel("Frequency", size=18);
    plt.xticks(size=14); plt.yticks(size=14);
    plt.show()

def draw_avg_reply_users_count(data, channel='Random'):
    """who commands many user reply?"""

    data.groupby('sender_name')['reply_users_count'].mean().sort_values(ascending=False)[:20].plot(kind='bar',
     figsize=(15,7.5));
    plt.title(f'Average Number of reply user count per Sender in #{channel}', size=20, fontweight='bold')
    plt.xlabel("Sender Name", size=18); plt.ylabel("Frequency", size=18);
    plt.xticks(size=14); plt.yticks(size=14);
    plt.show()

def draw_wordcloud(msg_content, week):    
    # word cloud visualization
    allWords = ' '.join([twts for twts in msg_content])
    wordCloud = WordCloud(background_color='#975429', width=500, height=300, random_state=21, max_words=500, mode='RGBA',
                            max_font_size=140, stopwords=stopwords.words('english')).generate(allWords)
    plt.figure(figsize=(15, 7.5))
    plt.imshow(wordCloud, interpolation="bilinear")
    plt.axis('off')
    plt.tight_layout()
    plt.title(f'WordCloud for {week}', size=30)
    plt.show()

def draw_user_reaction(data, channel='General'):
    data.groupby('sender_name')[['reply_count', 'reply_users_count']].sum()\
        .sort_values(by='reply_count',ascending=False)[:10].plot(kind='bar', figsize=(15, 7.5))
    plt.title(f'User with the most reaction in #{channel}', size=25);
    plt.xlabel("Sender Name", size=18); plt.ylabel("Frequency", size=18);
    plt.xticks(size=14); plt.yticks(size=14);
    plt.show()

# %% [markdown]
# ## Insight Extraction
#
# Below are some useful questions to answer. Feel free to explore to answer other interesting questions that may be of help to get insight about student's behaviour, need, and future performance

# %%
# which user has the highest number of reply counts?

# %%
# Find the user with the highest reply count

user_reply_counts = week_1_5_sample_data.groupby('sender_name')['reply_count'].sum()
highest_reply_user = user_reply_counts.idxmax()
highest_reply_count = user_reply_counts.max()

print(f"The user with the highest number of reply counts is '{highest_reply_user}' with {highest_reply_count} replies.")
# Out:
# The user with the highest number of reply counts is 'Cristian Wilson' with 255 replies.

# %%
# Top and bottom 10 users by Reply Count
top_reply_users = week_1_5_sample_data.groupby('sender_name')['reply_count'].sum().sort_values(ascending=False).head(10)
bottom_reply_users = week_1_5_sample_data.groupby('sender_name')['reply_count'].sum().sort_values(ascending=True).head(10)

# %%
# Top and bottom 10 users by Message Count
top_message_users = week_1_5_sample_data['sender_name'].value_counts().head(10)
bottom_message_users = week_1_5_sample_data['sender_name'].value_counts().tail(10)

# %%
# Relationship between # of messages and # of reactions

# %%
# Classify messages into different categories such as questions, answers, comments, etc.

# %%
# Which users got the most reactions?

# %%
# Model topics mentioned in the channel

# %%
# What are the topics that got the most reactions?

# %% [markdown]
# ### Harder questions to look into

# %%
# Based on messages, reactions, references shared, and other relevant data such as classification of questions into techical question, comment, answer, aorder stu the python, statistics, and sql skill level of a user?
